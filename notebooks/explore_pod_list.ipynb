# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/openb_pod_list_default.csv')

# %%
df.head()

# %%
df.shape

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df['qos'].value_counts()

# %%
df['pod_phase'].value_counts()

# %%
int(df.creation_time.min())

# %%
creation_time_max = int(df.creation_time.max())

# %%
# creation_time is in seconds so we need to convert it to days
creation_time_max / 86400

# %%
# binning
bins = pd.cut(df.creation_time, bins=30)

# %%
df.groupby(bins, observed=True).size()

# %%
# checking if there is are any processes where deletion time is less than creation time (anomaly)
(df.deletion_time < df.creation_time).sum()

# %%
# check if requested cpu is <=0
(df.cpu_milli <= 0).sum()
