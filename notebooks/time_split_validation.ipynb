# %%
import pandas as pd

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from ml.features.time_split import time_based_split

df = pd.read_parquet('../data/processed/feature_table_15min.parquet')
train, val, test = time_based_split(df)

# %%
train

# %%
print('train:', len(train), train.bucket_start.min(), '-', train.bucket_start.max())
print('val:  ', len(val), val.bucket_start.min(), '-', val.bucket_start.max())
print('test: ', len(test), test.bucket_start.min(), '-', test.bucket_start.max())
